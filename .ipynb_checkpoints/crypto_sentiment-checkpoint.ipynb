# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Wai Fatt
# [nltk_data]     Yee\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Set environment variables from the .env in the local environment
load_dotenv()
# Out:
# True

# %%
# Read your api key environment variable
api_key = os.getenv('NEWS_API_KEY')
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Bitcoin: {btc_headlines['totalResults']}")
# Out:
# Total articles about Bitcoin: 9580

# %%
# Show sample article
btc_headlines["articles"][5]
# Out:
# {'source': {'id': None, 'name': 'Gizmodo.com'},
#  'author': 'Lauren Leffer',
#  'title': 'Fidelity Wants to Include Bitcoin in 401(k) Plans; Elizabeth Warren and the Labor Department Have Concerns',
#  'description': "The nation's largest retirement plan provider is getting pushback for allowing investors to put a portion of their savings into cryptocurrency.",
#  'url': 'https://gizmodo.com/fidelity-wants-bitcoin-added-to-401-k-retirement-plans-1848885502',
#  'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/2413ade0375c0f5b3affe4029f35315c.jpg',
#  'publishedAt': '2022-05-05T18:10:00Z',
#  'content': 'If youve ever felt like introducing some Vegas-style odds into your retirement plan, youre finally in luck.\r\nLast week, Fidelity Investments announced that it would allow investors to put part of the… [+3239 chars]'}

# %%
# Fetch the Ethereum news articles
eth_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Ethereum: {eth_headlines['totalResults']}")
# Out:
# Total articles about Ethereum: 4601

# %%
# Show sample article
eth_headlines["articles"][99]
# Out:
# {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#  'author': 'insider@insider.com (Hanna Horvath)',
#  'title': '3 things to consider before adding bitcoin to your retirement portfolio, according to a financial planner',
#  'description': 'If you want to add bitcoin to your retirement portfolio, be sure you understand the risks involved and consider how close you are to retiring.',
#  'url': 'https://www.businessinsider.com/personal-finance/things-to-consider-before-adding-bitcoin-retirement-2022-5',
#  'urlToImage': 'https://i.insider.com/628254239147a30018b4854b?width=1200&format=jpeg',
#  'publishedAt': '2022-05-16T14:57:15Z',
#  'content': "What was once a niche investment is now becoming mainstream a vast majority of adults have at least heard about cryptocurrency, and 16% say they've invested or traded crypto. Now, the investment may … [+4441 chars]"}

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1  2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2  2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 3  2022-05-16  As a kid, I remember when my father tried to u...    0.3818
# 4  2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
#
#    positive  negative  neutral
# 0     0.036     0.000    0.964
# 1     0.056     0.061    0.882
# 2     0.085     0.143    0.772
# 3     0.114     0.052    0.833
# 4     0.072     0.000    0.928

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "date": date,
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 1  2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 2  2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
# 3  2022-04-26  April 26 (Reuters) - Ether has promised to do ...    0.5346
# 4  2022-04-26  Ethereum is preparing for an upgrade thats bee...    0.2716
#
#    positive  negative  neutral
# 0     0.135     0.000    0.865
# 1     0.046     0.075    0.879
# 2     0.000     0.055    0.945
# 3     0.142     0.000    0.858
# 4     0.065     0.000    0.935

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.002554    0.058010    0.060270    0.881720
# std      0.429137    0.064135    0.073622    0.091061
# min     -0.831600    0.000000    0.000000    0.557000
# 25%     -0.286625    0.000000    0.000000    0.829750
# 50%      0.000000    0.053000    0.051500    0.887500
# 75%      0.340000    0.096000    0.085250    0.945500
# max      0.865500    0.263000    0.299000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.082862    0.075660    0.04895    0.875410
# std      0.473191    0.086535    0.06245    0.090481
# min     -0.836000    0.000000    0.00000    0.622000
# 25%     -0.284450    0.000000    0.00000    0.828250
# 50%      0.000000    0.062000    0.03450    0.895000
# 75%      0.458800    0.127250    0.07500    0.935000
# max      0.952000    0.378000    0.29900    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Between the two coins, Ethereum appears to have the higher mean positve score.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum recorded the highest compound score between the two coins.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum appears to have attained the highest positve score compared to Bitcoin.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {"I'm", "ha", "has", "may", "quite", "you've", "you're", "today", "also", "say", "said", "week", "said", "sent", "us", "wa", "yesterday", "yet"}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase and remove stop words   
    output = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    return output

# %%
# Create a new tokens column for Bitcoin
btc_tokenized_words=[]
n = 0
for n in range(len(btc_df)):
    btc_tokenized_words.append(tokenizer(btc_df.loc[n,'text']))
    n+=1
btc_df['Tokenized Words']=btc_tokenized_words
btc_df
# Out:
#           date                                               text  compound  \
# 0   2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1   2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2   2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 3   2022-05-16  As a kid, I remember when my father tried to u...    0.3818
# 4   2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
# ..         ...                                                ...       ...
# 95  2022-05-08  Former Bank of Canada governor David Dodge is ...    0.2732
# 96  2022-05-13  Global stocks climbed on Friday after a volati...    0.6124
# 97  2022-05-13  The cryptocurrency world has had a rough May s...    0.0258
# 98  2022-05-13  US stocks ended Friday with steep gains, partl...   -0.1655
# 99  2022-05-13  Gold Bullion from the American Precious Metals...    0.2732
#
#     positive  negative  neutral  \
# 0      0.036     0.000    0.964
# 1      0.056     0.061    0.882
# 2      0.085     0.143    0.772
# 3      0.114     0.052    0.833
# 4      0.072     0.000    0.928
# ..       ...       ...      ...
# 95     0.135     0.076    0.789
# 96     0.135     0.000    0.865
# 97     0.064     0.061    0.875
# 98     0.096     0.088    0.816
# 99     0.102     0.072    0.826
#
#                                       Tokenized Words
# 0   [even, though, number, womenfocused, crypto, s...
# 1   [bitcoin, mining, site, powered, otherwise, lo...
# 2   [warren, buffett, always, bitcoin, skeptic, bi...
# 3   [kid, remember, father, tried, use, broom, han...
# 4   [image, source, getty, imagesthe, value, bitco...
# ..                                                ...
# 95  [former, bank, canada, governor, david, dodge,...
# 96  [global, stock, climbed, friday, volatile, plu...
# 97  [cryptocurrency, world, rough, farsince, start...
# 98  [stock, ended, friday, steep, gain, partly, re...
# 99  [gold, bullion, american, precious, metals, ex...
#
# [100 rows x 7 columns]

# %%
# Create a new tokens column for Ethereum
eth_tokenized_words=[]
n = 0
for n in range(len(btc_df)):
    eth_tokenized_words.append(tokenizer(eth_df.loc[n,'text']))
    n+=1
eth_df['Tokenized Words']=eth_tokenized_words
eth_df
# Out:
#           date                                               text  compound  \
# 0   2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 1   2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 2   2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
# 3   2022-04-26  April 26 (Reuters) - Ether has promised to do ...    0.5346
# 4   2022-04-26  Ethereum is preparing for an upgrade thats bee...    0.2716
# ..         ...                                                ...       ...
# 95  2022-04-27  SolanaNFT trading volume has jumped thanks to ...    0.8134
# 96  2022-04-26  Want a cryptocurrency that can stand the test ...   -0.2263
# 97  2022-04-27  You don't need a fortune to get started in cry...    0.4019
# 98  2022-04-25  Bloomberg's Levine: Can you give me an intuiti...    0.3612
# 99  2022-05-16  What was once a niche investment is now becomi...    0.0000
#
#     positive  negative  neutral  \
# 0      0.135     0.000    0.865
# 1      0.046     0.075    0.879
# 2      0.000     0.055    0.945
# 3      0.142     0.000    0.858
# 4      0.065     0.000    0.935
# ..       ...       ...      ...
# 95     0.225     0.000    0.775
# 96     0.037     0.062    0.901
# 97     0.074     0.000    0.926
# 98     0.101     0.000    0.899
# 99     0.000     0.000    1.000
#
#                                       Tokenized Words
# 0   [meta, revealed, nfts, work, instagram, usbase...
# 1   [multibillion, dollar, cryptocurrency, company...
# 2   [bored, ape, yacht, club, creator, yuga, labs,...
# 3   [april, reuters, ether, promised, better, prom...
# 4   [ethereum, preparing, upgrade, thats, describe...
# ..                                                ...
# 95  [solananfttrading, volume, jumped, thanks, new...
# 96  [want, cryptocurrency, stand, test, time, look...
# 97  [dont, need, fortune, get, started, crypto, st...
# 98  [bloombergs, levine, give, intuitive, understa...
# 99  [niche, investment, becoming, mainstream, vast...
#
# [100 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
#Convert nested list to a flat list
btc_processed =[]
for elem in btc_tokenized_words:
    for item in elem:
        btc_processed.append(item)

# %%
btc_headlines["articles"][1]
# Out:
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Justine Calma',
#  'title': 'Why fossil fuel companies see green in Bitcoin mining projects',
#  'description': 'ExxonMobil and other fossil fuel companies have turned to Bitcoin mining to address a gas problem. But their plans come with risks.',
#  'url': 'https://www.theverge.com/2022/5/4/23055761/exxonmobil-cryptomining-bitcoin-methane-gas',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/BZdljrBbt8tBl6oCCnckcDKqe6g=/0x90:4608x2503/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file
('bored', 'apes'): 2, ('apes', 'yacht'): 2, ('club', 'nfts'): 1, ('nfts', 'last'): 1, ('last', 'night'): 1, ('night', 'held'): 1, ('held', 'virtual'): 1, ('virtual', 'land'): 2, ('land', 'sale'): 2, ('sale', 'report'): 1, ('report', 'bloomberg'): 1, ('bloomberg', 'raising'): 1, ('raising', 'nearly'): 1, ('nearly', 'third'): 1, ('third', 'billion'): 1, ('billion', 'dollarsat'): 1, ('dollarsat', 'ab'): 1, ('ab', 'char'): 1, ('char', 'editorial'): 1, ('editorial', 'independencewe'): 1, ('independencewe', 'want'): 1, ('want', 'help'): 1, ('help', 'make'): 1, ('make', 'informed'): 1, ('informed', 'decision'): 1, ('decision', 'link'): 1, ('link', 'page'): 1, ('page', 'clearly'): 1, ('clearly', 'marked'): 1, ('marked', 'take'): 1, ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_processed, N=10)
# Out:
# [('char', 91),
#  ('bitcoin', 53),
#  ('reuters', 33),
#  ('cryptocurrency', 32),
#  ('cryptocurrencies', 19),
#  ('world', 18),
#  ('crypto', 15),
#  ('market', 15),
#  ('investor', 13),
#  ('april', 12)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_processed, N=10)
# Out:
# [('char', 100),
#  ('cryptocurrency', 26),
#  ('crypto', 23),
#  ('bitcoin', 21),
#  ('world', 17),
#  ('cryptocurrencies', 15),
#  ('ethereum', 12),
#  ('last', 12),
#  ('nfts', 11),
#  ('digital', 10)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string = ' '.join(btc_processed)
btc_wc = WordCloud().generate(big_string)
plt.imshow(btc_wc)

# %%
# Generate the Ethereum word cloud
big_string = ' '.join(eth_processed)
eth_wc = WordCloud().generate(big_string)
plt.imshow(eth_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_texts = []
n=0
for n in range (len(btc_df)):
    btc_texts.append(btc_df.loc[n,'text'])
    n += 1
btc_string = ' '.join([str(item) for item in btc_texts])
btc_string
# Out:
# 'Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars] A Bitcoin mining site powered by otherwise lost gas from an oil well near Linden, Texas, on April 4th, 2022. | Photo by FRANCOIS PICARD/AFP via Getty Images\r\n\n \n\n Of all the corporate climate hype fl… [+6544 chars] Warren Buffett has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over the weekend. Buffett made it clear that his opposition to crypt… [+2297 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars] Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world\'s largest cryp… [+2164 chars] If youve ever felt like introducing some Vegas-style odds into your retirement plan, youre finally in luck.\r\nLast week, Fidelity Investments announced that it would allow investors to put part of the… [+3239 chars] Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and the US Treasury is now ready to clamp down on them when hostile government… [+1432 chars] BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars] April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars] May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 20.9% from the year\'s low o… [+337 chars] Posted \r\nFrom Bitcoin\'s dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week\'s big stories in cryptocurrencies. Kristy Kilburn reports. May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 35% from t… [+351 chars] Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars] At a Mexican restaurant in North London a few weeks ago, a handful of small-time but remarkably discerning retail cryptocurrency investors predicted that terra and luna would crash. Several of them w… [+2779 chars] May 10 (Reuters) - Bitcoin has scant experience with rising interest rates, posing perils for investors looking to capitalize on its dramatic drop.\r\nThe cryptocurrency has tanked along with other ris… [+4315 chars] The Central African Republic has adopted bitcoin as legal tender, making it the second nation in the world -- after El Salvador -- to do so. On Wednesday, President Faustin Archange Touadera\'s office… [+1078 chars] Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validating blockchain transactions, which underpins bitcoin, was not capable of scaling up to cope with … [+1063 chars] If you want to pay online, you need to register an account and provide credit card information. If you don\'t have a credit card, you can pay with ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_string)
# Add a title to the document
doc.user_data['title'] = "Named Entity Recognition: Bitcoin"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Named Entity Recognition: Bitcoin</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Now, even though there are a number of women-focused crypto spaces,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odeniran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars] A Bitcoin mining site powered by otherwise lost gas from an oil well near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . | Photo by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FRANCOIS PICARD/AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br> Of all the corporate climate hype fl… [+6544 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Warren Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  made it clear that his opposition to crypt… [+2297 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of snow. You can guess how well that … [+3390 chars] Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The value of Bitcoin continued to fall over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as it dropped below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27,630
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ), according to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidelity Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that it would allow investors to put part of the… [+3239 chars] Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is now ready to clamp down on them when hostile government… [+1432 chars] BTC fell to its lowest level since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as prices dropped below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     33,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  to start
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     
fidelity, HONG KONG, May 13, Reuters, Friday, ATM, Hong Kong, 2017, Kin Cheung, AP, NEW YORK, Bitcoin!, Weeks, iPhone, January 2007, Steve Jobs, New York City, January 2021, Miami, Francis Suarez, Twitter, The City of Miami, #, ORLANDO, Fla., May 5, Reuters, U.S., the 2000s, ORLANDO, Fla., May 12, Reuters, this week, Getty Images, Nonfungible Tidbits, weekly, this week, May 12, Reuters, Thursday, 2021, 16-m, a wild week, third, Cayman, recent days, NEW YORK, May 11, LONDON, April 29, Reuters Breakingviews, 400%, 1,400%, the past two, LONDON, HONG KONG, May 12, Reuters, the next year, over 30%, 2020, Terra, LUNA, more than 97 percent, the past few days, UST, 2 cents, early Thursday, OTTAWA, April 25, Reuters, Canadian, Monday, Conservative, INTEL, Intel, Blockscale, 2022, Bitcoin Magazine, April 2022, US, Friday, nearly 1,000, Fed, Jerome Powell, GPV, 31%, YoY, Q1, $43.5 billion, multibillion-dollar, Coinbases, Brian Armstrong, NEW YORK, Fidelity, Tuesda, Warren Buffett, Charlie Munger, Apple, Activision Blizzard, last quarter, Berkshire Hathaway's, this year, Metaverse, this year, Metaverse, April 2 ...

# %%
# List all Entities
print([ent.text for ent in doc.ents])
# Out:
# ['Odeniran', 'Linden', 'Texas', 'April 4th', '2022', 'FRANCOIS PICARD/AFP', 'Getty Images', 'Warren Buffett', 'the weekend', 'Buffett', 'nearly three feet', 'Getty Images', 'the weekend', '34,000', '27,630', 'Coinbase', 'Last week', 'Fidelity Investments', 'the US Treasury', 'last July', '33,000', 'the week', 'last week', 'Fed', 'April 26', 'Reuters', '5.1%', '38,391.36', 'Tuesday', '2,229.82', 'Bitcoin', '16%', 'year', '+339', 'May 4', 'Reuters', '5.7%', '39,862.84', 'Wednesday', '2,102.94', 'Bitcoin', '20.9%', 'year', 'Bitcoin', 'Gucci', 'week', 'Kristy Kilburn', 'May 11', 'Reuters', '7.23%', '28,758.29', '22:05 GMT', 'Wednesday', '2,241.68', 'Bitcoin', '40.4%', '+361', 'May 9', 'Reuters', '7.81%', '31,333.41', 'Monday', '2,655.98', 'Bitcoin', '35%', 'AMC', 'April 15', 'AMC', 'Adam Aron', 'moviego', 'Mexican', 'North London', 'a few weeks ago', 'May 10', 'Reuters', '+4315', 'The Central African Republic', 'second', 'El Salvador', 'Wednesday', 'Faustin Archange', 'Sam Bankman-Fried', 'FTX', 'El Salvador', 'first', 'September', '$36 million', 'over 50%', 'Thursday', 'April 28', 'Reuters', "Central African Republic's", 'April 27', 'Reuters', 'Wednesday', 'first', 'Africa', 'second', "South Africa's", 'one trillion rand', 'Zambia', 'Mopani', 'Nasdaq', 'Tom Scally', '05/13', 'Cryptocurrencies', 'early Friday', 'TerraUSD', 'May 5', 'Reuters', 'Jack Dorsey', 'Thursday', 'the first quarter', '05/09', 'Nasdaq', 'HONG KONG', 'May 16', 'Reuters', 'Monday', 'the weekend', 'European', 'April 29', 'Reuters', 'The Swiss National Bank', 'Thomas Jordan', 'annual', 'Friday', 'HONG KONG', 'May 10', 'Reuters', 'Australian', 'Canadian', 'Tuesday', 'Warhol', 'the week to May 13', 'Olivia Chan', 'Transform', 'July 19', 'July 20 - 28', 'today', 'May 16', 'Reuters', 'FTX', 'Bitcoin', 'Ukraine', 'Fed', 'US', 'Tuesday', "the previous day's", '500', 'one-year', "El Salvador's", 'Bloomberg', 'Nayib Bukele', '1', '40 days ago', '47,454', '34,007', '28%.About a third', 'this week', 'HONG KONG', 'May 9', 'Reuters', 'January on Monday', 'Monday', 'morning', 'Bitcoin', '32,940', 'more than 50%', '68,990', 'November', 'Bitcoin', 'MicroStrategy', '16%', 'Monday', '2020', 'Bitcoin', '18%', 'Yesterday', 'Bitcoin: Mexico', 'Senate', 'the Mexican Republic', 'HONG KONG', 'May 10', 'Reuters', 'fourth', 'third', 'Tuesday', 'Berkshire Hathaway', 'Warren Buffett', 'Bitcoin', 'just a few years ago', 'Spacex', 'Elon Musk', '$7.139 billion', 'Twitter', 'SINGAPORE', 'May 13', 'Reuters', 'Friday', '30,000', 'TerraUSD', 'LONDON', 'NEW YORK', 'May 12', 'Reuters', 'TerraUSD', 'one', 'Thursday', 'NEW YORK', 'AP', 'a wild week', 'third', 'Charley Cooper', 'R3', 'May 13', 'Reuters', "Central Africa's", 'Friday', 'weeks', 'the Central African Republic', 'May 5', 'Reuters', 'Gucci', 'U.S.', 'Italian', 'LONDON', 'May 2', 'Reuters Breakingviews', 'Silicon Valley', 'Central African Republic', 'CAR', 'Wednesday', 'LONDON', 'May 4', 'Reuters Breakingviews', 'David Solomons', '$100 billion', 'April 26', 'Reuters', 'No.2', 'Cryptocurrencies', 'early Friday', 'TerraUSD', 'Tom Scally', 'Luna', 'Joe Mullally', 'CAR', 'decades', 'Russian', 'the Wagner Group', '16%', '$59 million', 'Miami', 'Bitcoin', '23', '16', 'one', '27,000', 'Thursday', 'morning', '2020', 'one', 'REUTERS', 'Dado Ruvic/Fil', 'NEW YORK', 'April 29', 'Reuters', 'U.S.', 'the latest week', 'Reuters', 'U.S. Commodity Futures Trading Commission', 'Due - Due', 'Fidelity', 'Fidelity', 'HONG KONG', 'May 13', 'Reuters', 'Friday', 'ATM', 'Hong Kong', '2017', 'Kin Cheung', 'AP', 'NEW YORK', 'Bitcoin!', 'Weeks', 'iPhone', 'January 2007', 'Steve Jobs', 'New York City', 'January 2021', 'Miami', 'Francis Suarez', 'Twitter', 'The City of Miami', '#', 'ORLANDO', 'Fla.', 'May 5', 'Reuters', 'U.S.', 'the 2000s', 'ORLANDO', 'Fla.', 'May 12', 'Reuters', 'this week', 'Getty Images', 'Nonfungible Tidbits', 'weekly', 'this week', 'May 12', 'Reuters', 'Thursday', '2021', '16-m', 'a wild week', 'third', 'Cayman', 'recent days', 'NEW YORK', 'May 11', ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_texts = []
n=0
for n in range (len(eth_df)):
    eth_texts.append(eth_df.loc[n,'text'])
    n += 1
eth_string = ' '.join([str(item) for item in eth_texts])
eth_string
# Out:
# 'Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you\'ve bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars] A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the Ethereum cryptocurrency.\r\nYuga Labs, the comp… [+3475 chars] When Bored Ape Yacht Club creators Yuga Labs announced its Otherside NFT collection would launch on April 30, it was predicted by many to be the biggest NFT launch ever. Otherside is an upcoming Bore… [+6669 chars] April 26 (Reuters) - Ether has promised to do better. It has promised to go to the next level, edging out crypto rivals and even outshining the godfather, bitcoin. But the clock\'s ticking.\r\nThe No.2 … [+4092 chars] Ethereum is preparing for an upgrade thats been described as the single most important event in crypto history.\r\nThe transition would overhaul the infrastructure of the worlds second-largest blockcha… [+2824 chars] Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars] There\'s a new metaverse project from the creators of the "Bored Apes Yacht Club" NFTs. Last night they held a "virtual land" sale, reports Bloomberg, raising nearly a third of a billion dollars.At ab… [+2023 chars] Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars] Early this week, the Ukrainian Computer Emergency Response Team and Slovakian cybersecurity firm ESET warned that Russia\'s notorious GRU Sandworm hackers had targeted high-voltage electrical substati… [+3937 chars] 40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars] When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars] April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars] May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 20.9% from the year\'s low o… [+337 chars] May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 35% from t… [+351 chars] If you ever wanted to buy an NFT based on Ethereum, you would have to pay a transaction fee to register it on the blockchain. Last week, that fee skyrocketed to unprecedented levels.\r\nSo you might ha… [+7216 chars] 9 with 8 posters participating\r\nNvidia began releasing LHR (or Lite Hash Rate) graphics cards last year\xa0to slow down their cryptocurrency mining performance and make them less appealing to non-gamers… [+2182 chars] BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars] ApeCoin, the native cryptocurrency of the APE Ecosystem, slid 16% Monday in a viciously volatile tradi ...

# %%
# Run the NER processor on all of the text
doc_ = nlp(eth_string)

# Add a title to the document
doc.user_data['title'] = "Named Entity Recognition: Ethereum"

# %%
# Render the visualization
displacy.render(doc_, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has revealed more of how NFTs will work on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based test, you can show what you've bought or created for free by connecting your
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  account to a compatible digital walle… [+1223 chars] A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the comp… [+3475 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bored Ape Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  creators
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otherside
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT collection would launch on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it was predicted by many to be the biggest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launch ever. Otherside is an upcoming Bore… [+6669 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The transition would overhaul the infrastructure of the worlds
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -largest blockcha… [+2824 chars] Dogecoiners unite! Movie theater chain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Aron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced that
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moviego
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [+1603 chars] There's a new metaverse project from the creators of
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the &quot;Bored Apes Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# &quot; NFTs.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  they held a &quot;virtual land&quot; sale, reports
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %%
# List all Entities
print([ent.text for ent in doc_.ents])
# Out:
# ['Meta', 'Instagram', 'US', 'Instagram', 'Ethereum', 'Yuga Labs', 'Bored Ape Yacht Club', 'Yuga Labs', 'Otherside', 'April 30', 'NFT', 'April 26', 'Reuters', 'No.2', 'second', 'AMC', 'April 15', 'AMC', 'Adam Aron', 'moviego', 'the "Bored Apes Yacht Club', 'Last night', 'Bloomberg', 'nearly a third', 'a billion dollars', 'Early this week', 'the Ukrainian Computer Emergency Response Team', 'Slovakian', 'Russia', 'GRU Sandworm', '40 days ago', '47,454', '34,007', '28%.About a third', 'this week', 'Nvidia', 'Ethereum', 'April 26', 'Reuters', '5.1%', '38,391.36', 'Tuesday', '2,229.82', 'Bitcoin', '16%', 'year', '+339', 'May 4', 'Reuters', '5.7%', '39,862.84', 'Wednesday', '2,102.94', 'Bitcoin', '20.9%', 'year', 'May 11', 'Reuters', '7.23%', '28,758.29', '22:05 GMT', 'Wednesday', '2,241.68', 'Bitcoin', '40.4%', '+361', 'May 9', 'Reuters', '7.81%', '31,333.41', 'Monday', '2,655.98', 'Bitcoin', '35%', 'NFT', 'Ethereum', 'Last week', '9', '8', 'Nvidia', 'LHR', 'Lite Hash Rate', 'last year', 'last July', '33,000', 'the week', 'last week', 'Fed', 'Ecosystem', '16%', 'Monday', '14.60', 'Transform', 'July 19', 'July 20 - 28', 'today', 'coali', 'Getty Images', 'the weekend', '34,000', '27,630', 'Coinbase', 'April 22', 'Reuters', 'Stripe Inc', 'May 5', 'Reuters', 'Gucci', 'U.S.', 'Italian', 'This week', 'FBI', 'Ronin', 'North Korean', 'Saturday', 'Yuga Labs―the', 'the Bored Apes Yacht Club NFT', 'Otherdeeds', 'Terras UST', '40 cents', 'Alex Castro', 'a crushing few days', 'Terra', 'a week', 'The U.S. Department of Justice', 'two', 'European', 'North Korean', '2019', 'One', '30', 'a tough month', '25%', '30%', '81', 'a month ago', 'multibillion-dollar', '1%', 'Bitcoin and Ethereum', 'eToro', 'CopyPortfolios', 'CopyTrader', 'HONG KONG', 'May 9', 'Reuters', 'January on Monday', 'Bitcoin, Ethereum', 'DogeCoin', 'June 29, 2021', 'REUTERS', 'Dado Ruvic/Illustration/File Photo/Fi', 'one', 'REUTERS', 'Dado Ruvic/Fil', 'Jack Dorsey', 'Twitter', 'Last week', 'the Senate of the Republic in Mexico', 'thousands', 'Digital', 'one', 'Dirk Hohndel', 'Slashdot', 'the last five years', 'VMware', '+1660', 'Monday', 'morning', 'Bitcoin', '32,940', 'more than 50%', '68,990', 'November', 'Bitcoin', 'the past few years', 'Metaverse', '2022', 'Ethereum', '2021', '2,000 acres', 'about US$4 million', 'Digital', '7.6bn', 'last week', 'this week', 'Getty Images', 'Nonfungible Tidbits', 'weekly', 'this week', '404', 'as low as $0.94', 'Thursday', 'TerraUSD', '0.9', 'Earlier this year', 'Meta', 'Mark Zuckerberg', 'Instagram', 'the start of the month', '$600 billion', '2020', '3.0', '3.0', 'third', 'the World Wide Web', 'Tim Berners-Lee', '2022', 'OpenSea', 'one', 'NFT', 'Hungry', '23', '16', 'one', '27,000', 'Thursday', 'morning', '2020', 'eToro', 'Coinbase', 'eToro', 'April 25', 'Reuters', 'multibillion-dollar', 'Coinbases', 'Brian Armstrong', 'Jam City', 'first', 'today', 'arXivLabs', 'arXivLabs', 'US', 'this week', 'North Korean', '$625 million', 'Axie Infinity', 'morning', 'Fed', 'DeFi', 'Due - Due', 'Fidelity', 'Fidelity', 'Thursday', 'US', 'last month', 'Crypto', 'Stripe', 'Getty', 'Stripe', 'Friday', 'Twitter', 'Coinbase', 'NFT', 'Ethereum', 'Sarah Tew', 'CNET', 'Coinbase', 'NFT', 'Wednesday', 'Last fall', 'Bored Ape Yacht Club', 'Yuga Labs', 'thousands of dollars', 'Ethereum', 'blockchai', 'Cybersecurity Dive', 'daily', 'Cybersecurity Dive', 'daily', 'The Crypto Show', 'Bitcoin', 'one', 'almost 20%', 'the past ten days', 'this weeks', 'Bloomberg', 'Bloomberg Intelligence', 'Active Share Replacing Alpha', 'this week', 'Friday', 'SEC', 'Nvidia', '$5.5 million', 'GPU', '2', '3', '3', 'May 3', 'Reuters', '2022', 'the last year', 'March 22', 'Motherboard', 'This week', 'Neal Stephenson', 'sci-fi', '1992', 'Snow Crash', 'first', 'Thursday', 'Stephenson', 'first', 'NFT', 'Neophyte MMXXII', '94', 'Ster', 'Transform', 'July 19', 'July 20 - 28', 'today', 'Crypto', 'thousands', 'Ethereum(ETH -3.30%', 'second', 'Twitter', 'years', 'Cryptocurrencies', 'the last few years', 'o ...

# %% [markdown]
# ---
